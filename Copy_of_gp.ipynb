# %% [markdown]
# <a href="https://colab.research.google.com/github/latifahaljurayyan/insightApp/blob/main/Copy_of_gp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google_play_scraper
# Out:
# Requirement already satisfied: google_play_scraper in /usr/local/lib/python3.12/dist-packages (1.2.7)

# %%
from google_play_scraper import reviews, Sort
import pandas as pd

# %%
apps = {
    "Amazon": "com.amazon.mShop.android.shopping",
    "Shein": "com.zzkko",
    "AliExpress": "com.alibaba.aliexpresshd",
    "Noon": "com.noon.buyerapp",
    "Trendyol": "trendyol.com"
}

# %%
def label_sentiment(rating):
    if rating <= 2:
        return "Negative"
    elif rating == 3:
        return "Neutral"
    else:
        return "Positive"

# %%
all_reviews = []

for app_name, app_id in apps.items():
    print(f"Fetching reviews for {app_name}...")

    result, _ = reviews(
        app_id,
        lang="en",
        country="us",
        sort=Sort.NEWEST,
        count=3000
    )

    for r in result:
        all_reviews.append({
            "app_name": app_name,
            "review_text": r["content"],
            "rating": r["score"],
            "sentiment_label": label_sentiment(r["score"])
        })
# Out:
# Fetching reviews for Amazon...
# Fetching reviews for Shein...
# Fetching reviews for AliExpress...
# Fetching reviews for Noon...
# Fetching reviews for Trendyol...

# %%
df = pd.DataFrame(all_reviews)
df.head()
# Out:
#   app_name                                        review_text  rating  \
# 0   Amazon                                      I love Amazon       5
# 1   Amazon                                               Good       5
# 2   Amazon                                   so easy to shop!       5
# 3   Amazon  worst experience, I ordered expensive item not...       1
# 4   Amazon                                              great       5
#
#   sentiment_label
# 0        Positive
# 1        Positive
# 2        Positive
# 3        Negative
# 4        Positive

# %%
import re



def clean_text(text):

    text = re.sub(r"http\S+", "", str(text))

    text = re.sub(r"[^a-zA-Z\s]", "", text)

    text = text.lower()

    return text



df["clean_review"] = df["review_text"].apply(clean_text)

# %%
df.to_csv("google_play_app_reviews.csv", index=False)

# %%
df[["review_text", "clean_review"]].head(10)
# Out:
#                                          review_text  \
# 0                                      I love Amazon
# 1                                               Good
# 2                                   so easy to shop!
# 3  worst experience, I ordered expensive item not...
# 4                                              great
# 5                                  Yous are evil!!!!
# 6  I enjoy using the app, the specials and discou...
# 7  the app integrated ai into tasks it didnt need...
# 8  Removed the Orders screen, making managing exp...
# 9        Delivery drivers are amazing 👏 Good service
#
#                                         clean_review
# 0                                      i love amazon
# 1                                               good
# 2                                    so easy to shop
# 3  worst experience i ordered expensive item not ...
# 4                                              great
# 5                                      yous are evil
# 6  i enjoy using the app the specials and discoun...
# 7  the app integrated ai into tasks it didnt need...
# 8  removed the orders screen making managing expe...
# 9         delivery drivers are amazing  good service

# %%
import nltk
nltk.download('punkt_tab')
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
df["Tokens"]= df["clean_review"].apply(word_tokenize)
df[[ "clean_review","Tokens"]].head(5)
# Out:
#                                         clean_review  \
# 0                                      i love amazon
# 1                                               good
# 2                                    so easy to shop
# 3  worst experience i ordered expensive item not ...
# 4                                              great
#
#                                               Tokens
# 0                                  [i, love, amazon]
# 1                                             [good]
# 2                               [so, easy, to, shop]
# 3  [worst, experience, i, ordered, expensive, ite...
# 4                                            [great]

# %%
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import nltk


nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')

r
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def remove_stopwords(tokens):
    return [word for word in tokens if word not in stop_words]

df["Tokens_No_Stopwords"] = df["Tokens"].apply(remove_stopwords)


def lemmatize_tokens(tokens):
    return [lemmatizer.lemmatize(word) for word in tokens]

df["Tokens_No_Stopwords_Lemmatized"] = df["Tokens_No_Stopwords"].apply(lemmatize_tokens)


df[["Tokens", "Tokens_No_Stopwords", "Tokens_No_Stopwords_Lemmatized"]].head()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
#                                               Tokens  \
# 0                                  [i, love, amazon]
# 1                                             [good]
# 2                               [so, easy, to, shop]
# 3  [worst, experience, i, ordered, expensive, ite...
# 4                                            [great]
#
#                                  Tokens_No_Stopwords  \
# 0                                     [love, amazon]
# 1                                             [good]
# 2                                       [easy, shop]
# 3  [worst, experience, ordered, expensive, item, ...
# 4                                            [great]
#
#                       Tokens_No_Stopwords_Lemmatized
# 0                                     [love, amazon]
# 1                                             [good]
# 2                                       [easy, shop]
# 3  [worst, experience, ordered, expensive, item, ...
# 4                                            [great]

# %%
df.to_csv("google_play_app_reviews.csv", index=False)

# %%
from google.colab import files
files.download("google_play_app_reviews.csv")
