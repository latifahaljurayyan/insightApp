# %% [markdown]
# <a href="https://colab.research.google.com/github/latifahaljurayyan/insightApp/blob/main/Copy_of_gp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google_play_scraper
# Out:
# Collecting google_play_scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 1.9 MB/s eta 0:00:00
# Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google_play_scraper
# Successfully installed google_play_scraper-1.2.7

# %%
from google_play_scraper import reviews, Sort
import pandas as pd

# %%
apps = {
    "Amazon": "com.amazon.mShop.android.shopping",
    "Shein": "com.zzkko",
    "AliExpress": "com.alibaba.aliexpresshd",
    "Noon": "com.noon.buyerapp",
    "Trendyol": "trendyol.com"
}

# %%
def label_sentiment(rating):
    if rating <= 2:
        return "Negative"
    elif rating == 3:
        return "Neutral"
    else:
        return "Positive"

# %%
all_reviews = []

for app_name, app_id in apps.items():
    print(f"Fetching reviews for {app_name}...")

    result, _ = reviews(
        app_id,
        lang="en",
        country="us",
        sort=Sort.NEWEST,
        count=3000
    )

    for r in result:
        all_reviews.append({
            "app_name": app_name,
            "review_text": r["content"],
            "rating": r["score"],
            "sentiment_label": label_sentiment(r["score"])
        })
# Out:
# Fetching reviews for Amazon...
# Fetching reviews for Shein...
# Fetching reviews for AliExpress...
# Fetching reviews for Noon...
# Fetching reviews for Trendyol...

# %%
df = pd.DataFrame(all_reviews)
df.head()
# Out:
#   app_name                                        review_text  rating  \
# 0   Amazon  I have never had an issue with Amazon it does ...       5
# 1   Amazon  they switched the way to cancel Amazon Prime. ...       1
# 2   Amazon  Smooth shopping experience with quick delivery...       5
# 3   Amazon  Amazon is good but the thing is Amazon is just...       2
# 4   Amazon                                            Amazing       5
#
#   sentiment_label
# 0        Positive
# 1        Negative
# 2        Positive
# 3        Negative
# 4        Positive

# %%
import re



def clean_text(text):

    text = re.sub(r"http\S+", "", str(text))

    text = re.sub(r"[^a-zA-Z\s]", "", text)

    text = text.lower()

    return text



df["clean_review"] = df["review_text"].apply(clean_text)

# %%
df.to_csv("google_play_app_reviews.csv", index=False)

# %%
df[["review_text", "clean_review"]].head(10)
# Out:
#                                          review_text  \
# 0  I have never had an issue with Amazon it does ...
# 1  they switched the way to cancel Amazon Prime. ...
# 2  Smooth shopping experience with quick delivery...
# 3  Amazon is good but the thing is Amazon is just...
# 4                                            Amazing
# 5  the Amazon business app is absolutely the wors...
# 6  Very cluttered. I don't like the layout at all...
# 7  The quality of Amazon is not what it used to b...
# 8  The current UI/UX is frustrating. As a regular...
# 9   easy to get what you need w ithout leaving house
#
#                                         clean_review
# 0  i have never had an issue with amazon it does ...
# 1  they switched the way to cancel amazon prime s...
# 2  smooth shopping experience with quick delivery...
# 3  amazon is good but the thing is amazon is just...
# 4                                            amazing
# 5  the amazon business app is absolutely the wors...
# 6  very cluttered i dont like the layout at all t...
# 7  the quality of amazon is not what it used to b...
# 8  the current uiux is frustrating as a regular b...
# 9   easy to get what you need w ithout leaving house

# %%
from google.colab import files
files.download("google_play_app_reviews.csv")
