# %% [markdown]
# <a href="https://colab.research.google.com/github/latifahaljurayyan/insightApp/blob/main/Copy_of_gp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google_play_scraper
# Out:
# Requirement already satisfied: google_play_scraper in /usr/local/lib/python3.12/dist-packages (1.2.7)

# %%
from google_play_scraper import reviews, Sort
import pandas as pd

# %%
apps = {
    "Amazon": "com.amazon.mShop.android.shopping",
    "Shein": "com.zzkko",
    "AliExpress": "com.alibaba.aliexpresshd",
    "Noon": "com.noon.buyerapp",
    "Trendyol": "trendyol.com"
}

# %%
def label_sentiment(rating):
    if rating <= 2:
        return "Negative"
    elif rating == 3:
        return "Neutral"
    else:
        return "Positive"

# %%
all_reviews = []

for app_name, app_id in apps.items():
    print(f"Fetching reviews for {app_name}...")

    result, _ = reviews(
        app_id,
        lang="en",
        country="us",
        sort=Sort.NEWEST,
        count=3000
    )

    for r in result:
        all_reviews.append({
            "app_name": app_name,
            "review_text": r["content"],
            "rating": r["score"],
            "sentiment_label": label_sentiment(r["score"])
        })
# Out:
# Fetching reviews for Amazon...
# Fetching reviews for Shein...
# Fetching reviews for AliExpress...
# Fetching reviews for Noon...
# Fetching reviews for Trendyol...

# %%
df = pd.DataFrame(all_reviews)
df.head()
# Out:
#   app_name                                        review_text  rating  \
# 0   Amazon  Not available on my Galaxy 6 after I was told ...       1
# 1   Amazon                                              great       5
# 2   Amazon         I don't like the new update. it's terrible       1
# 3   Amazon                                               😎😎😎😎       5
# 4   Amazon  My orders are already in the locker, but the a...       1
#
#   sentiment_label
# 0        Negative
# 1        Positive
# 2        Negative
# 3        Positive
# 4        Negative

# %%
import re



def clean_text(text):

    text = re.sub(r"http\S+", "", str(text))

    text = re.sub(r"[^a-zA-Z\s]", "", text)

    text = text.lower()

    return text



df["clean_review"] = df["review_text"].apply(clean_text)

# %%
df.to_csv("google_play_app_reviews.csv", index=False)

# %%
df[["review_text", "clean_review"]].head(10)
# Out:
#                                          review_text  \
# 0  Not available on my Galaxy 6 after I was told ...
# 1                                              great
# 2         I don't like the new update. it's terrible
# 3                                               😎😎😎😎
# 4  My orders are already in the locker, but the a...
# 5  بصراحه في سرقه جدا انا حوالي في ٧٠٠ جنيه معاهم...
# 6  NOT TRUSTWORTHY. they deliberately made it dif...
# 7  Love buying Ama,on due to the safety of return...
# 8  got a new phone with the same phone number and...
# 9                    great except app keeps crashing
#
#                                         clean_review
# 0  not available on my galaxy  after i was told m...
# 1                                              great
# 2            i dont like the new update its terrible
# 3
# 4  my orders are already in the locker but the ap...
# 5                                                ...
# 6  not trustworthy they deliberately made it diff...
# 7  love buying amaon due to the safety of returns...
# 8  got a new phone with the same phone number and...
# 9                    great except app keeps crashing

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df["Tokens"]= df["clean_review"].apply(word_tokenize)
df[[ "clean_review","Tokens"]].head(5)
# Out:
#                                         clean_review  \
# 0  not available on my galaxy  after i was told m...
# 1                                              great
# 2            i dont like the new update its terrible
# 3
# 4  my orders are already in the locker but the ap...
#
#                                               Tokens
# 0  [not, available, on, my, galaxy, after, i, was...
# 1                                            [great]
# 2   [i, dont, like, the, new, update, its, terrible]
# 3                                                 []
# 4  [my, orders, are, already, in, the, locker, bu...

# %%
df.to_csv("google_play_app_reviews.csv", index=False)

# %%
from google.colab import files
files.download("google_play_app_reviews.csv")
