# %% [markdown]
# <a href="https://colab.research.google.com/github/latifahaljurayyan/insightApp/blob/main/Copy_of_gp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google_play_scraper
# Out:
# Requirement already satisfied: google_play_scraper in /usr/local/lib/python3.12/dist-packages (1.2.7)

# %%
from google_play_scraper import reviews, Sort
import pandas as pd

# %%
apps = {
    "Amazon": "com.amazon.mShop.android.shopping",
    "Shein": "com.zzkko",
    "AliExpress": "com.alibaba.aliexpresshd",
    "Noon": "com.noon.buyerapp",
    "Trendyol": "trendyol.com"
}

# %%
def label_sentiment(rating):
    if rating <= 2:
        return "Negative"
    elif rating == 3:
        return "Neutral"
    else:
        return "Positive"

# %%
all_reviews = []

for app_name, app_id in apps.items():
    print(f"Fetching reviews for {app_name}...")

    result, _ = reviews(
        app_id,
        lang="en",
        country="us",
        sort=Sort.NEWEST,
        count=3000
    )

    for r in result:
        all_reviews.append({
            "app_name": app_name,
            "review_text": r["content"],
            "rating": r["score"],
            "sentiment_label": label_sentiment(r["score"])
        })
# Out:
# Fetching reviews for Amazon...
# Fetching reviews for Shein...
# Fetching reviews for AliExpress...
# Fetching reviews for Noon...
# Fetching reviews for Trendyol...

# %%
df = pd.DataFrame(all_reviews)
df.head()
# Out:
#   app_name                                        review_text  rating  \
# 0   Amazon                                               Good       5
# 1   Amazon                                   so easy to shop!       5
# 2   Amazon  worst experience, I ordered expensive item not...       1
# 3   Amazon                                              great       5
# 4   Amazon                                  Yous are evil!!!!       1
#
#   sentiment_label
# 0        Positive
# 1        Positive
# 2        Negative
# 3        Positive
# 4        Negative

# %%
import re



def clean_text(text):

    text = re.sub(r"http\S+", "", str(text))

    text = re.sub(r"[^a-zA-Z\s]", "", text)

    text = text.lower()

    return text



df["clean_review"] = df["review_text"].apply(clean_text)

# %%
df.to_csv("google_play_app_reviews.csv", index=False)

# %%
df[["review_text", "clean_review"]].head(10)
# Out:
#                                          review_text  \
# 0                                               Good
# 1                                   so easy to shop!
# 2  worst experience, I ordered expensive item not...
# 3                                              great
# 4                                  Yous are evil!!!!
# 5  I enjoy using the app, the specials and discou...
# 6  the app integrated ai into tasks it didnt need...
# 7  Removed the Orders screen, making managing exp...
# 8        Delivery drivers are amazing 👏 Good service
# 9                                          So easy..
#
#                                         clean_review
# 0                                               good
# 1                                    so easy to shop
# 2  worst experience i ordered expensive item not ...
# 3                                              great
# 4                                      yous are evil
# 5  i enjoy using the app the specials and discoun...
# 6  the app integrated ai into tasks it didnt need...
# 7  removed the orders screen making managing expe...
# 8         delivery drivers are amazing  good service
# 9                                            so easy

# %%
import nltk
nltk.download('punkt_tab')
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
df["Tokens"]= df["clean_review"].apply(word_tokenize)
df[[ "clean_review","Tokens"]].head(5)
# Out:
#                                         clean_review  \
# 0                                               good
# 1                                    so easy to shop
# 2  worst experience i ordered expensive item not ...
# 3                                              great
# 4                                      yous are evil
#
#                                               Tokens
# 0                                             [good]
# 1                               [so, easy, to, shop]
# 2  [worst, experience, i, ordered, expensive, ite...
# 3                                            [great]
# 4                                  [yous, are, evil]

# %%
df.to_csv("google_play_app_reviews.csv", index=False)

# %%
from google.colab import files
files.download("google_play_app_reviews.csv")
