# %% [markdown]
# <a href="https://colab.research.google.com/github/latifahaljurayyan/insightApp/blob/main/GP2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title
# !pip install google_play_scraper

# %%
from google_play_scraper import reviews, Sort
import pandas as pd
import matplotlib.pyplot as plt

# %%
apps = {
    "Amazon": "com.amazon.mShop.android.shopping",
    "Shein": "com.zzkko",
    "AliExpress": "com.alibaba.aliexpresshd",
    "Noon": "com.noon.buyerapp",
    "Trendyol": "trendyol.com"
}

# %%
def label_sentiment(rating):
    if rating <= 2:
        return "Negative"
    elif rating == 3:
        return "Neutral"
    else:
        return "Positive"

# %%
all_reviews = []

for app_name, app_id in apps.items():
    print(f"Fetching reviews for {app_name}...")

    for star in [1, 2, 3, 4, 5]:
        try:
            result, _ = reviews(
                app_id,
                lang="en",
                country="us",
                sort=Sort.NEWEST,
                count=2000,
                filter_score_with=star
            )
            for r in result:
                all_reviews.append({
                    "app_name": app_name,
                    "review_text": r["content"],
                    "rating": r["score"],
                    "sentiment_label": label_sentiment(r["score"])
                })
        except Exception as e:
            print(f"Error for {app_name} star {star}: {e}")
# Out:
# Fetching reviews for Amazon...
# Fetching reviews for Shein...
# Fetching reviews for AliExpress...
# Fetching reviews for Noon...
# Fetching reviews for Trendyol...

# %%
df = pd.DataFrame(all_reviews)
df.head()
# Out:
#   app_name                                        review_text  rating  \
# 0   Amazon       no way to talk to someone about fake charges       1
# 1   Amazon  stop harassing me to join prime ! i don't want...       1
# 2   Amazon  What's with no longer seeing the map when trac...       1
# 3   Amazon  Unable to cancel free Prime trial! Oh, I can f...       1
# 4   Amazon  might just cancel Amazon after this experience...       1
#
#   sentiment_label
# 0        Negative
# 1        Negative
# 2        Negative
# 3        Negative
# 4        Negative

# %%
df.to_csv("dataset_reviews.csv", index=False)

# %%
from google.colab import files
files.download("dataset_reviews.csv")
